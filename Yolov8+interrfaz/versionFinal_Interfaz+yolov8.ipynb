# %% [markdown]
# Interfaz Funcional para el usuario, donde podra aplicar los filtros

# %%
import os
import cv2
import numpy as np
import tkinter as tk
import vlc
from tkinter import filedialog
from datetime import timedelta
from PIL import Image, ImageTk
from ultralytics import YOLO
from PIL import ImageGrab
from pathlib import Path
import shutil
import Funcion_homografia

class MediaPlayerApp(tk.Tk):
    def __init__(self):
        super().__init__()
        self.title("Media Player (Volley-Var)")
        self.geometry("800x600")
        self.configure(bg="#f0f0f0")
        self.initialize_player()
    
    def initialize_player(self):
        self.instance = vlc.Instance()
        self.media_player = self.instance.media_player_new()
        self.current_file = None
        self.playing_video = False
        self.video_paused = False
        self.create_widgets()

    def create_widgets(self):
        self.media_canvas = tk.Canvas(self, bg="black", width=800, height=400)
        self.media_canvas.pack(pady=10, fill=tk.BOTH, expand=True)
        self.image_label = tk.Label(self.media_canvas, bg="black") #####
        self.image_label.pack(fill=tk.BOTH, expand=True)#######
        self.select_file_button = tk.Button(
            self,
            text="Select File",
            font=("Arial", 12, "bold"),
            command=self.select_file,
        )
        self.select_file_button.pack(pady=5)
        self.time_label = tk.Label(
            self,
            text="00:00:00 / 00:00:00",
            font=("Arial", 12, "bold"),
            fg="#555555",
            bg="#f0f0f0",
        )
        self.time_label.pack(pady=5)
        self.control_buttons_frame = tk.Frame(self, bg="#f0f0f0")
        self.control_buttons_frame.pack(pady=5)

        self.play_button = tk.Button(
            self.control_buttons_frame,
            text="Play",
            font=("Arial", 12, "bold"),
            bg="#4CAF50",
            fg="white",
            command=self.play_video,
        )
        self.play_button.pack(side=tk.LEFT, padx=5, pady=5)
        self.pause_button = tk.Button(
            self.control_buttons_frame,
            text="Pause",
            font=("Arial", 12, "bold"),
            bg="#FF9800",
            fg="white",
            command=self.pause_video,
        )
        self.pause_button.pack(side=tk.LEFT, padx=10, pady=5)
        self.stop_button = tk.Button(
            self.control_buttons_frame,
            text="Stop",
            font=("Arial", 12, "bold"),
            bg="#F44336",
            fg="white",
            command=self.stop,
        )
        self.stop_button.pack(side=tk.LEFT, pady=5)
        self.fast_forward_button = tk.Button(
            self.control_buttons_frame,
            text="Fast Forward",
            font=("Arial", 12, "bold"),
            bg="#2196F3",
            fg="white",
            command=self.fast_forward,
        )
        self.fast_forward_button.pack(side=tk.LEFT, padx=10, pady=5)
        self.rewind_button = tk.Button(
            self.control_buttons_frame,
            text="Rewind",
            font=("Arial", 12, "bold"),
            bg="#2196F3",
            fg="white",
            command=self.rewind,
        )
        self.rewind_button.pack(side=tk.LEFT, pady=5)
        self.progress_bar = VideoProgressBar(
            self, self.set_video_position, bg="#e0e0e0", highlightthickness=0
        )
        self.progress_bar.pack(fill=tk.X, padx=10, pady=5)
        #nuevo boton, aplicar YOLO
        self.yolo_button = tk.Button(
            self.control_buttons_frame,
            text="Apply YOLO",
            font=("Arial", 12, "bold"),
            bg="#8B4513",
            fg="white",
            command=self.apply_yolo,
        )
        self.yolo_button.pack(side=tk.LEFT, padx=10, pady=5)
        self.screenshot_button = tk.Button(
            self.control_buttons_frame,
            text="Take Screenshot",
            font=("Arial", 12, "bold"),
            bg="#607D8B",
            fg="white",
            command=self.take_screenshot,
        )
        self.screenshot_button.pack(side=tk.LEFT, padx=10, pady=5)
    

    def play_yolo_video(self, yolo_video_path):
        # Detener la reproducción actual si hay un video en curso
        self.stop()

        # Establecer el nuevo archivo de video y reproducirlo
        media = self.instance.media_new(yolo_video_path)
        self.media_player.set_media(media)
        self.media_player.set_hwnd(self.media_canvas.winfo_id())
        self.media_player.play()
        self.playing_video = True

        #almacena la ruta del video actual
        self.current_file = yolo_video_path
    
    def apply_yolo(self):

        if self.current_file:     
            # Cargar el modelo YOLO

            yolo_model = YOLO('best.pt')
            
            yolo_output_directory = 'runs/detect/predict'

            # Eliminar la carpeta 'predict' si ya existe
            if os.path.exists(yolo_output_directory):
                shutil.rmtree(yolo_output_directory)

            # Procesar el video con YOLO
            results = yolo_model(source=self.current_file, save=True)

            # Obtener la ruta del video procesado por YOLO
            yolo_output_filename = Path(self.current_file).stem + '.avi'
            yolo_video_path = os.path.join(yolo_output_directory, yolo_output_filename)
            
            #print("RUTA YOLO ",yolo_video_path)
            self.play_yolo_video(yolo_video_path)


    def select_file(self):
        file_path = filedialog.askopenfilename(
            filetypes=[("Media Files", "*.mp4 *.avi")]
        )
        if file_path:
            self.current_file = file_path
            self.time_label.config(text="00:00:00 / " + self.get_duration_str())
            self.play_video()

    def get_duration_str(self):
        if self.playing_video:
            total_duration = self.media_player.get_length()
            total_duration_str = str(timedelta(milliseconds=total_duration))[:-3]
            return total_duration_str
        return "00:00:00"

    def play_video(self):
        if not self.playing_video and self.current_file:
            media = self.instance.media_new(self.current_file)
            self.media_player.set_media(media)
            self.media_player.set_hwnd(self.media_canvas.winfo_id())
            self.media_player.play()
            self.playing_video = True

    def fast_forward(self):
        if self.playing_video:
            current_time = self.media_player.get_time() + 10000
            self.media_player.set_time(current_time)

    def rewind(self):
        if self.playing_video:
            current_time = self.media_player.get_time() - 10000
            self.media_player.set_time(current_time)

    

    def pause_video(self):
        if self.playing_video:
            if self.video_paused:
                self.media_player.play()
                self.video_paused = False
                self.pause_button.config(text="Pause")
            else:
                self.media_player.pause()
                self.video_paused = True
                self.pause_button.config(text="Resume")


    def capture_screenshot(self, path):
        # Obtener el screenshot de toda la pantalla
        screenshot = self.get_full_screen_screenshot()

        # Guardar el screenshot como imagen usando Pillow
        screenshot.save(path)

    def take_screenshot(self):
        if self.playing_video:
        # Obtener una referencia a la barra de progreso
            progress_bar = self.progress_bar

        # Generar un nombre de archivo único utilizando el contador
            name =  f"screenshot_{progress_bar.screenshot_counter}.png"
            screenshot_path = os.path.join("frame", name)
            screenshot_path = os.path.abspath(screenshot_path)

        # Capturar el screenshot y guardarlo
            self.capture_screenshot(screenshot_path)

        # Incrementar el contador para el próximo screenshot
            progress_bar.increment_screenshot_counter()
            imagen_homografiada = Funcion_homografia.homography_from_image(screenshot_path)
            yolo_model = YOLO('best.pt')
            yolo_model(source=imagen_homografiada, save = True)
            
    def capture_screenshot(self, path):
        # Obtener el screenshot de toda la pantalla
        screenshot = self.get_full_screen_screenshot()

        # Guardar el screenshot como imagen usando Pillow
        screenshot.save(path)


    def get_full_screen_screenshot(self):
    # Tomar un screenshot de toda la pantalla
        screenshot = ImageGrab.grab()

        return screenshot

    def mouse_handler(event, x, y, flags, data) :
        if event == cv2.EVENT_LBUTTONDOWN :
            cv2.circle(data['im'], (x,y), 3, (0,0,255), 5, 16)
            cv2.imshow("Image", data['im'])
        if len(data['points']) < 4 :
            data['points'].append([x,y])
   

    def stop(self):
        if self.playing_video:
            self.media_player.stop()
            self.playing_video = False
        self.time_label.config(text="00:00:00 / " + self.get_duration_str())

    def set_video_position(self, value):
        if self.playing_video:
            total_duration = self.media_player.get_length()
            position = int((float(value) / 100) * total_duration)
            self.media_player.set_time(position)

    def update_video_progress(self):
        if self.playing_video:
            total_duration = self.media_player.get_length()
            if total_duration != 0:
                current_time = self.media_player.get_time()
                progress_percentage = (current_time / total_duration) * 100
                self.progress_bar.set(progress_percentage)
                current_time_str = str(timedelta(milliseconds=current_time))[:-3]
                total_duration_str = str(timedelta(milliseconds=total_duration))[:-3]
                self.time_label.config(text=f"{current_time_str}/{total_duration_str}")
        self.after(1000, self.update_video_progress)

class VideoProgressBar(tk.Scale):
    def __init__(self, master, command, **kwargs):
        kwargs["showvalue"] = False
        super().__init__(
            master,
            from_=0,
            to=100,
            orient=tk.HORIZONTAL,
            length=800,
            command=command,
            **kwargs,
        )
        self.bind("<Button-1>", self.on_click)
        self.screenshot_counter = 1  # Inicializar el contador de screenshots propio

    def on_click(self, event):
        if self.cget("state") == tk.NORMAL:
            value = (event.x / self.winfo_width()) * 100
            self.set(value)

    def increment_screenshot_counter(self):
        self.screenshot_counter += 1

if __name__ == "__main__":
    app = MediaPlayerApp()
    app.update_video_progress()
    app.mainloop()
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 363.0ms
# video 1/1 (2/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 350.0ms
# video 1/1 (3/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 338.0ms
# video 1/1 (4/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 347.0ms
# video 1/1 (5/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 325.0ms
# video 1/1 (6/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 340.0ms
# video 1/1 (7/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 348.0ms
# video 1/1 (8/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 338.0ms
# video 1/1 (9/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 316.0ms
# video 1/1 (10/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 333.0ms
# video 1/1 (11/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 357.0ms
# video 1/1 (12/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 354.0ms
# video 1/1 (13/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 360.0ms
# video 1/1 (14/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 420.0ms
# video 1/1 (15/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 362.0ms
# video 1/1 (16/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 334.0ms
# video 1/1 (17/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 362.0ms
# video 1/1 (18/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 353.0ms
# video 1/1 (19/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 349.0ms
# video 1/1 (20/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 368.0ms
# video 1/1 (21/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 384.0ms
# video 1/1 (22/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 386.0ms
# video 1/1 (23/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 365.0ms
# video 1/1 (24/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 375.0ms
# video 1/1 (25/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 358.0ms
# video 1/1 (26/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 358.0ms
# video 1/1 (27/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 333.0ms
# video 1/1 (28/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 333.0ms
# video 1/1 (29/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 317.0ms
# video 1/1 (30/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 319.0ms
# video 1/1 (31/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 338.0ms
# video 1/1 (32/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 315.0ms
# video 1/1 (33/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 333.0ms
# video 1/1 (34/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 340.0ms
# video 1/1 (35/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 314.0ms
# video 1/1 (36/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 343.0ms
# video 1/1 (37/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 327.0ms
# video 1/1 (38/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 337.0ms
# video 1/1 (39/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 340.0ms
# video 1/1 (40/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 327.0ms
# video 1/1 (41/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 318.0ms
# video 1/1 (42/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 322.0ms
# video 1/1 (43/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 339.0ms
# video 1/1 (44/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 327.0ms
# video 1/1 (45/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 326.0ms
# video 1/1 (46/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 341.0ms
# video 1/1 (47/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 321.0ms
# video 1/1 (48/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 349.0ms
# video 1/1 (49/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 334.0ms
# video 1/1 (50/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 316.0ms
# video 1/1 (51/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 317.0ms
# video 1/1 (52/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 320.0ms
# video 1/1 (53/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 314.0ms
# video 1/1 (54/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 3 volleyballs, 309.0ms
# video 1/1 (55/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 308.0ms
# video 1/1 (56/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 3 volleyballs, 322.0ms
# video 1/1 (57/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 325.0ms
# video 1/1 (58/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 328.0ms
# video 1/1 (59/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 3 volleyballs, 335.0ms
# video 1/1 (60/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 3 volleyballs, 312.0ms
# video 1/1 (61/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 3 volleyballs, 333.0ms
# video 1/1 (62/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 332.0ms
# video 1/1 (63/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 312.0ms
# video 1/1 (64/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 321.0ms
# video 1/1 (65/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 310.0ms
# video 1/1 (66/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 331.0ms
# video 1/1 (67/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 323.0ms
# video 1/1 (68/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 324.0ms
# Speed: 1.9ms preprocess, 337.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 347.0ms
# video 1/1 (2/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 339.0ms
# video 1/1 (3/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 336.0ms
# video 1/1 (4/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 347.0ms
# video 1/1 (5/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 367.0ms
# video 1/1 (6/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 316.0ms
# video 1/1 (7/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 338.0ms
# video 1/1 (8/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 345.0ms
# video 1/1 (9/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 348.0ms
# video 1/1 (10/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 340.0ms
# video 1/1 (11/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 345.0ms
# video 1/1 (12/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 328.0ms
# video 1/1 (13/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 339.0ms
# video 1/1 (14/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 334.0ms
# video 1/1 (15/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 339.0ms
# video 1/1 (16/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 321.0ms
# video 1/1 (17/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 330.0ms
# video 1/1 (18/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 319.0ms
# video 1/1 (19/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 345.0ms
# video 1/1 (20/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 340.0ms
# video 1/1 (21/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 320.0ms
# video 1/1 (22/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 326.0ms
# video 1/1 (23/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 335.0ms
# video 1/1 (24/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 334.0ms
# video 1/1 (25/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 328.0ms
# video 1/1 (26/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 324.0ms
# video 1/1 (27/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 304.0ms
# video 1/1 (28/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 325.0ms
# video 1/1 (29/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 333.0ms
# video 1/1 (30/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 315.0ms
# video 1/1 (31/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 311.0ms
# video 1/1 (32/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 335.0ms
# video 1/1 (33/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 339.0ms
# video 1/1 (34/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 337.0ms
# video 1/1 (35/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 337.0ms
# video 1/1 (36/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 328.0ms
# video 1/1 (37/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 311.0ms
# video 1/1 (38/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 304.0ms
# video 1/1 (39/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 316.0ms
# video 1/1 (40/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 329.0ms
# video 1/1 (41/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 333.0ms
# video 1/1 (42/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 315.0ms
# video 1/1 (43/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 339.0ms
# video 1/1 (44/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 340.0ms
# video 1/1 (45/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 319.0ms
# video 1/1 (46/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 337.0ms
# video 1/1 (47/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 319.0ms
# video 1/1 (48/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 305.0ms
# video 1/1 (49/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 320.0ms
# video 1/1 (50/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 323.0ms
# video 1/1 (51/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 (no detections), 334.0ms
# video 1/1 (52/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 333.0ms
# video 1/1 (53/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 325.0ms
# video 1/1 (54/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 3 volleyballs, 338.0ms
# video 1/1 (55/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 301.0ms
# video 1/1 (56/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 3 volleyballs, 317.0ms
# video 1/1 (57/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 322.0ms
# video 1/1 (58/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 332.0ms
# video 1/1 (59/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 3 volleyballs, 335.0ms
# video 1/1 (60/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 3 volleyballs, 327.0ms
# video 1/1 (61/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 3 volleyballs, 328.0ms
# video 1/1 (62/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 333.0ms
# video 1/1 (63/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 330.0ms
# video 1/1 (64/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 337.0ms
# video 1/1 (65/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 332.0ms
# video 1/1 (66/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 336.0ms
# video 1/1 (67/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 2 volleyballs, 335.0ms
# video 1/1 (68/68) C:\Users\josch\Downloads\WhatsApp Video 2023-11-19 at 9.14.36 PM.mp4: 384x640 1 volleyball, 322.0ms
# Speed: 2.0ms preprocess, 329.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict
