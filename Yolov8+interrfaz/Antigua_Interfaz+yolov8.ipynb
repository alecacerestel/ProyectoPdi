# %% [markdown]
# Interfaz Funcional para el usuario, donde podra aplicar los filtros

# %%
import os
import cv2
import numpy as np
import tkinter as tk
import vlc
from tkinter import filedialog
from datetime import timedelta
from PIL import Image, ImageTk
from ultralytics import YOLO
from PIL import ImageGrab
import Funcion_homografia



class MediaPlayerApp(tk.Tk):
    def __init__(self):
        super().__init__()
        self.title("Media Player (Volley-Var)")
        self.geometry("800x600")
        self.configure(bg="#f0f0f0")
        self.initialize_player()
    
    def initialize_player(self):
        self.instance = vlc.Instance()
        self.media_player = self.instance.media_player_new()
        self.current_file = None
        self.playing_video = False
        self.video_paused = False
        self.create_widgets()

    def create_widgets(self):
        self.media_canvas = tk.Canvas(self, bg="black", width=800, height=400)
        self.media_canvas.pack(pady=10, fill=tk.BOTH, expand=True)
        self.image_label = tk.Label(self.media_canvas, bg="black") #####
        self.image_label.pack(fill=tk.BOTH, expand=True)#######
        self.select_file_button = tk.Button(
            self,
            text="Select File",
            font=("Arial", 12, "bold"),
            command=self.select_file,
        )
        self.select_file_button.pack(pady=5)
        self.time_label = tk.Label(
            self,
            text="00:00:00 / 00:00:00",
            font=("Arial", 12, "bold"),
            fg="#555555",
            bg="#f0f0f0",
        )
        self.time_label.pack(pady=5)
        self.control_buttons_frame = tk.Frame(self, bg="#f0f0f0")
        self.control_buttons_frame.pack(pady=5)

        self.play_button = tk.Button(
            self.control_buttons_frame,
            text="Play",
            font=("Arial", 12, "bold"),
            bg="#4CAF50",
            fg="white",
            command=self.play_video,
        )
        self.play_button.pack(side=tk.LEFT, padx=5, pady=5)
        self.pause_button = tk.Button(
            self.control_buttons_frame,
            text="Pause",
            font=("Arial", 12, "bold"),
            bg="#FF9800",
            fg="white",
            command=self.pause_video,
        )
        self.pause_button.pack(side=tk.LEFT, padx=10, pady=5)
        self.stop_button = tk.Button(
            self.control_buttons_frame,
            text="Stop",
            font=("Arial", 12, "bold"),
            bg="#F44336",
            fg="white",
            command=self.stop,
        )
        self.stop_button.pack(side=tk.LEFT, pady=5)
        self.fast_forward_button = tk.Button(
            self.control_buttons_frame,
            text="Fast Forward",
            font=("Arial", 12, "bold"),
            bg="#2196F3",
            fg="white",
            command=self.fast_forward,
        )
        self.fast_forward_button.pack(side=tk.LEFT, padx=10, pady=5)
        self.rewind_button = tk.Button(
            self.control_buttons_frame,
            text="Rewind",
            font=("Arial", 12, "bold"),
            bg="#2196F3",
            fg="white",
            command=self.rewind,
        )
        self.rewind_button.pack(side=tk.LEFT, pady=5)
        self.progress_bar = VideoProgressBar(
            self, self.set_video_position, bg="#e0e0e0", highlightthickness=0
        )
        self.progress_bar.pack(fill=tk.X, padx=10, pady=5)
        #nuevo boton, aplicar YOLO
        self.yolo_button = tk.Button(
            self.control_buttons_frame,
            text="Apply YOLO",
            font=("Arial", 12, "bold"),
            bg="#8B4513",
            fg="white",
            command=self.apply_yolo,
        )
        self.yolo_button.pack(side=tk.LEFT, padx=10, pady=5)
        self.screenshot_button = tk.Button(
            self.control_buttons_frame,
            text="Take Screenshot",
            font=("Arial", 12, "bold"),
            bg="#607D8B",
            fg="white",
            command=self.take_screenshot,
        )
        self.screenshot_button.pack(side=tk.LEFT, padx=10, pady=5)
    

    def play_yolo_video(self, yolo_video_path):
        # Detener la reproducción actual si hay un video en curso
        self.stop()

        # Establecer el nuevo archivo de video y reproducirlo
        media = self.instance.media_new(yolo_video_path)
        self.media_player.set_media(media)
        self.media_player.set_hwnd(self.media_canvas.winfo_id())
        self.media_player.play()
        self.playing_video = True

    
    def apply_yolo(self):

        if self.current_file:     
            # Cargar el modelo YOLO
            yolo_model = YOLO('best.pt')

            # Procesar el video con YOLO
            results = yolo_model(source=self.current_file, save=True)

            # Obtener la ruta del video procesado por YOLO
            yolo_video_path = 'runs/detect/predict' + os.path.basename(self.current_file)
            
            self.play_yolo_video(yolo_video_path)

    def select_file(self):
        file_path = filedialog.askopenfilename(
            filetypes=[("Media Files", "*.mp4 *.avi")]
        )
        if file_path:
            self.current_file = file_path
            self.time_label.config(text="00:00:00 / " + self.get_duration_str())
            self.play_video()

    def get_duration_str(self):
        if self.playing_video:
            total_duration = self.media_player.get_length()
            total_duration_str = str(timedelta(milliseconds=total_duration))[:-3]
            return total_duration_str
        return "00:00:00"

    def play_video(self):
        if not self.playing_video:
            media = self.instance.media_new(self.current_file)
            self.media_player.set_media(media)
            self.media_player.set_hwnd(self.media_canvas.winfo_id())
            self.media_player.play()
            self.playing_video = True

    def fast_forward(self):
        if self.playing_video:
            current_time = self.media_player.get_time() + 10000
            self.media_player.set_time(current_time)

    def rewind(self):
        if self.playing_video:
            current_time = self.media_player.get_time() - 10000
            self.media_player.set_time(current_time)

    

    def pause_video(self):
        if self.playing_video:
            if self.video_paused:
                self.media_player.play()
                self.video_paused = False
                self.pause_button.config(text="Pause")
            else:
                self.media_player.pause()
                self.video_paused = True
                self.pause_button.config(text="Resume")


    def capture_screenshot(self, path):
        # Obtener el screenshot de toda la pantalla
        screenshot = self.get_full_screen_screenshot()

        # Guardar el screenshot como imagen usando Pillow
        screenshot.save(path)

    def take_screenshot(self):
        if self.playing_video:
        # Obtener una referencia a la barra de progreso
            progress_bar = self.progress_bar

        # Generar un nombre de archivo único utilizando el contador
            name =  f"screenshot_{progress_bar.screenshot_counter}.png"
            screenshot_path = os.path.join("frame", name)
            screenshot_path = os.path.abspath(screenshot_path)

        # Capturar el screenshot y guardarlo
            self.capture_screenshot(screenshot_path)

        # Incrementar el contador para el próximo screenshot
            progress_bar.increment_screenshot_counter()
            Funcion_homografia.homography_from_image(screenshot_path)
            '''
            #carga modelo yolo
            yolo_model = YOLO('best.pt')

            # Procesar el screemshot con YOLO

            Funcion_homografia.homography_from_image(screenshot_path)

            yolo_model(source=imagen_homografiada, save = True)

            print("Ruta del screenshot:", screenshot_path)

            #Obtener la ruta del video procesado por YOLO
            #yolo_video_path = 'runs/detect/predict' + os.path.basename(self.current_file)
            '''

    def capture_screenshot(self, path):
        # Obtener el screenshot de toda la pantalla
        screenshot = self.get_full_screen_screenshot()

        # Guardar el screenshot como imagen usando Pillow
        screenshot.save(path)


    def get_full_screen_screenshot(self):
    # Tomar un screenshot de toda la pantalla
        screenshot = ImageGrab.grab()

        return screenshot

    def mouse_handler(event, x, y, flags, data) :
        if event == cv2.EVENT_LBUTTONDOWN :
            cv2.circle(data['im'], (x,y), 3, (0,0,255), 5, 16)
            cv2.imshow("Image", data['im'])
        if len(data['points']) < 4 :
            data['points'].append([x,y])
   


    def stop(self):
        if self.playing_video:
            self.media_player.stop()
            self.playing_video = False
        self.time_label.config(text="00:00:00 / " + self.get_duration_str())

    def set_video_position(self, value):
        if self.playing_video:
            total_duration = self.media_player.get_length()
            position = int((float(value) / 100) * total_duration)
            self.media_player.set_time(position)

    def update_video_progress(self):
        if self.playing_video:
            total_duration = self.media_player.get_length()
            if total_duration != 0:
                current_time = self.media_player.get_time()
                progress_percentage = (current_time / total_duration) * 100
                self.progress_bar.set(progress_percentage)
                current_time_str = str(timedelta(milliseconds=current_time))[:-3]
                total_duration_str = str(timedelta(milliseconds=total_duration))[:-3]
                self.time_label.config(text=f"{current_time_str}/{total_duration_str}")
        self.after(1000, self.update_video_progress)

class VideoProgressBar(tk.Scale):
    def __init__(self, master, command, **kwargs):
        kwargs["showvalue"] = False
        super().__init__(
            master,
            from_=0,
            to=100,
            orient=tk.HORIZONTAL,
            length=800,
            command=command,
            **kwargs,
        )
        self.bind("<Button-1>", self.on_click)
        self.screenshot_counter = 1  # Inicializar el contador de screenshots propio

    def on_click(self, event):
        if self.cget("state") == tk.NORMAL:
            value = (event.x / self.winfo_width()) * 100
            self.set(value)

    def increment_screenshot_counter(self):
        self.screenshot_counter += 1

if __name__ == "__main__":
    app = MediaPlayerApp()
    app.update_video_progress()
    app.mainloop()
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 530.5ms
# video 1/1 (2/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 432.0ms
# video 1/1 (3/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 424.6ms
# video 1/1 (4/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 455.9ms
# video 1/1 (5/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 419.1ms
# video 1/1 (6/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 424.1ms
# video 1/1 (7/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 408.8ms
# video 1/1 (8/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 426.3ms
# video 1/1 (9/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 446.6ms
# video 1/1 (10/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 422.2ms
# video 1/1 (11/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 450.5ms
# video 1/1 (12/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 440.3ms
# video 1/1 (13/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 457.5ms
# video 1/1 (14/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 412.4ms
# video 1/1 (15/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 442.4ms
# video 1/1 (16/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 442.6ms
# video 1/1 (17/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 418.5ms
# video 1/1 (18/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 456.6ms
# video 1/1 (19/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 403.3ms
# video 1/1 (20/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 500.6ms
# video 1/1 (21/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 418.9ms
# video 1/1 (22/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 444.9ms
# video 1/1 (23/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 457.7ms
# video 1/1 (24/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 399.0ms
# video 1/1 (25/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 399.1ms
# video 1/1 (26/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 394.4ms
# video 1/1 (27/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 425.4ms
# video 1/1 (28/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 378.2ms
# video 1/1 (29/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 392.4ms
# video 1/1 (30/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 388.1ms
# video 1/1 (31/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 380.0ms
# video 1/1 (32/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 385.4ms
# video 1/1 (33/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 377.4ms
# video 1/1 (34/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 377.0ms
# video 1/1 (35/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 376.5ms
# video 1/1 (36/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 382.4ms
# video 1/1 (37/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 373.9ms
# video 1/1 (38/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 394.0ms
# video 1/1 (39/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 396.2ms
# video 1/1 (40/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 380.2ms
# video 1/1 (41/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 399.1ms
# video 1/1 (42/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 421.0ms
# video 1/1 (43/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 375.2ms
# video 1/1 (44/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 391.3ms
# video 1/1 (45/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 373.0ms
# video 1/1 (46/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 386.0ms
# video 1/1 (47/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 373.4ms
# video 1/1 (48/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 400.8ms
# video 1/1 (49/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 382.0ms
# video 1/1 (50/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 389.0ms
# video 1/1 (51/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 379.3ms
# video 1/1 (52/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 378.0ms
# video 1/1 (53/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 378.0ms
# video 1/1 (54/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 373.2ms
# video 1/1 (55/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 391.8ms
# video 1/1 (56/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 374.8ms
# video 1/1 (57/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 382.7ms
# video 1/1 (58/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 368.4ms
# video 1/1 (59/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 380.7ms
# video 1/1 (60/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 383.0ms
# video 1/1 (61/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 367.9ms
# video 1/1 (62/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 376.0ms
# video 1/1 (63/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 399.3ms
# video 1/1 (64/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 416.6ms
# video 1/1 (65/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 399.3ms
# video 1/1 (66/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 407.9ms
# video 1/1 (67/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 368.1ms
# video 1/1 (68/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 411.5ms
# video 1/1 (69/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 367.8ms
# video 1/1 (70/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 420.0ms
# video 1/1 (71/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 395.2ms
# video 1/1 (72/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 421.6ms
# video 1/1 (73/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 396.5ms
# video 1/1 (74/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 383.3ms
# video 1/1 (75/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 380.7ms
# video 1/1 (76/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 401.6ms
# video 1/1 (77/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 522.2ms
# video 1/1 (78/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 373.8ms
# video 1/1 (79/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 388.5ms
# video 1/1 (80/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 384.4ms
# video 1/1 (81/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 385.0ms
# video 1/1 (82/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 384.1ms
# video 1/1 (83/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 364.0ms
# video 1/1 (84/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 386.0ms
# video 1/1 (85/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 401.1ms
# video 1/1 (86/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 442.2ms
# video 1/1 (87/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 401.5ms
# video 1/1 (88/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 385.1ms
# video 1/1 (89/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 374.3ms
# video 1/1 (90/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 404.7ms
# video 1/1 (91/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 417.9ms
# video 1/1 (92/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 390.3ms
# video 1/1 (93/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 383.0ms
# video 1/1 (94/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 367.1ms
# video 1/1 (95/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 422.2ms
# video 1/1 (96/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 385.0ms
# video 1/1 (97/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 395.4ms
# video 1/1 (98/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 386.9ms
# video 1/1 (99/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 418.2ms
# video 1/1 (100/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 390.7ms
# video 1/1 (101/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 380.0ms
# video 1/1 (102/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 380.1ms
# video 1/1 (103/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 474.3ms
# video 1/1 (104/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 515.0ms
# video 1/1 (105/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 394.2ms
# video 1/1 (106/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 383.0ms
# video 1/1 (107/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 434.0ms
# video 1/1 (108/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 422.9ms
# video 1/1 (109/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 446.2ms
# video 1/1 (110/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 413.9ms
# video 1/1 (111/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 422.0ms
# video 1/1 (112/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 401.0ms
# video 1/1 (113/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 470.0ms
# video 1/1 (114/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 385.0ms
# video 1/1 (115/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 445.9ms
# video 1/1 (116/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 398.3ms
# video 1/1 (117/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 394.7ms
# video 1/1 (118/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 402.8ms
# video 1/1 (119/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 396.9ms
# video 1/1 (120/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 387.2ms
# video 1/1 (121/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 391.0ms
# video 1/1 (122/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 401.0ms
# video 1/1 (123/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 385.0ms
# video 1/1 (124/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 404.0ms
# video 1/1 (125/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 389.0ms
# video 1/1 (126/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 406.9ms
# video 1/1 (127/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 449.3ms
# video 1/1 (128/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 380.8ms
# video 1/1 (129/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 413.1ms
# video 1/1 (130/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 416.0ms
# video 1/1 (131/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 501.4ms
# video 1/1 (132/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 420.7ms
# video 1/1 (133/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 388.0ms
# video 1/1 (134/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 494.8ms
# video 1/1 (135/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 480.3ms
# video 1/1 (136/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 381.2ms
# video 1/1 (137/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 403.5ms
# video 1/1 (138/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 381.8ms
# video 1/1 (139/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 417.8ms
# video 1/1 (140/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 512.6ms
# video 1/1 (141/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 406.2ms
# video 1/1 (142/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 386.9ms
# video 1/1 (143/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 392.0ms
# video 1/1 (144/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 406.0ms
# video 1/1 (145/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 387.4ms
# video 1/1 (146/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 391.7ms
# video 1/1 (147/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 378.0ms
# video 1/1 (148/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 384.3ms
# video 1/1 (149/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 381.0ms
# video 1/1 (150/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 418.1ms
# video 1/1 (151/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 415.3ms
# video 1/1 (152/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 414.1ms
# video 1/1 (153/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 372.6ms
# video 1/1 (154/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 402.1ms
# video 1/1 (155/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 378.8ms
# video 1/1 (156/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 386.8ms
# video 1/1 (157/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 440.8ms
# video 1/1 (158/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 411.9ms
# video 1/1 (159/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 437.9ms
# video 1/1 (160/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 378.0ms
# video 1/1 (161/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 418.9ms
# video 1/1 (162/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 466.6ms
# video 1/1 (163/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 380.0ms
# video 1/1 (164/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 391.7ms
# video 1/1 (165/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 386.4ms
# video 1/1 (166/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 397.5ms
# video 1/1 (167/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 521.7ms
# video 1/1 (168/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 445.2ms
# video 1/1 (169/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 435.6ms
# video 1/1 (170/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 448.3ms
# video 1/1 (171/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 429.1ms
# video 1/1 (172/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 421.9ms
# video 1/1 (173/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 472.1ms
# video 1/1 (174/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 417.9ms
# video 1/1 (175/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 401.2ms
# video 1/1 (176/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 406.1ms
# video 1/1 (177/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 438.1ms
# video 1/1 (178/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 411.3ms
# video 1/1 (179/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 398.4ms
# video 1/1 (180/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 417.4ms
# video 1/1 (181/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 412.9ms
# video 1/1 (182/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 407.2ms
# video 1/1 (183/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 404.8ms
# video 1/1 (184/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 426.6ms
# video 1/1 (185/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 406.5ms
# video 1/1 (186/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 412.0ms
# video 1/1 (187/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 431.8ms
# video 1/1 (188/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 417.4ms
# video 1/1 (189/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 415.6ms
# video 1/1 (190/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 409.6ms
# video 1/1 (191/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 488.0ms
# video 1/1 (192/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 429.3ms
# video 1/1 (193/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 394.2ms
# video 1/1 (194/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 429.3ms
# video 1/1 (195/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 426.5ms
# video 1/1 (196/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 420.2ms
# video 1/1 (197/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 419.6ms
# video 1/1 (198/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 438.9ms
# video 1/1 (199/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 1 volleyball, 392.3ms
# video 1/1 (200/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 431.1ms
# video 1/1 (201/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 419.3ms
# video 1/1 (202/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 432.3ms
# video 1/1 (203/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 405.3ms
# video 1/1 (204/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 449.5ms
# video 1/1 (205/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 404.1ms
# video 1/1 (206/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 420.5ms
# video 1/1 (207/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 418.2ms
# video 1/1 (208/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 461.4ms
# video 1/1 (209/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 425.9ms
# video 1/1 (210/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 390.4ms
# video 1/1 (211/211) C:\Users\Usuario\Downloads\DJI_0461.MP4: 384x640 (no detections), 510.5ms
# Speed: 3.2ms preprocess, 410.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict2
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Usuario\AppData\Local\Temp\ipykernel_10160\689053296.py", line 220, in take_screenshot
#     Funcion_homografia.homography_from_image(screenshot_path + '/'+ name)
#   File "c:\Users\Usuario\Documents\ProyectoPdi\Yolov8+interrfaz\Funcion_homografia.py", line 27, in homography_from_image
#     im= cv2.imread(im_src)
#         ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\utils\patches.py", line 25, in imread
#     return cv2.imdecode(np.fromfile(filename, np.uint8), flags)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\Usuario\\Documents\\ProyectoPdi\\Yolov8+interrfaz\\frame\\screenshot_1.png/screenshot_1.png'
